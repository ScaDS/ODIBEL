# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import (StructType, StructField, StringType, ArrayType)
from pyspark.sql.functions import explode, col, from_json, concat_ws, regexp_extract, when
import os
from glob import glob

# Spark setup
os.environ["JAVA_HOME"] = "/local/d1/users/kv21supo/micromamba/envs/jupyter"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]

print("Starting Spark Session...")
spark = SparkSession.builder \
    .appName("Data Exploration") \
    .config("spark.driver.memory", "100g") \
    .config("spark.executor.cores", "72") \
    .config("spark.sql.shuffle.partitions", "360") \
    .config("spark.ui.enabled", "false") \
    .getOrCreate()
print("Spark Session started.")

# Load raw JSON-LD files
folderPath = "../unpacked/"
filePaths = glob(os.path.join(folderPath, "*.jsonld"))
dfRaw = spark.read.text(filePaths)
print("JSON files read successfully.")

# Schema of JSON rows
schema = StructType([
    StructField("subject", StringType(), True),
    StructField("predicate", StringType(), True),
    StructField("objects", StringType(), True)
])

# Parse JSON into struct
parsed_df = dfRaw.withColumn("jsonData", from_json(col("value"), schema))

# JSON-LD @id schema
id_schema = StructType([StructField("@id", StringType(), True)])

object_schema = ArrayType(
    StructType([
        StructField("object", StructType([
            StructField("@value", StringType(), True),
            StructField("@type", StringType(), True)
        ])),
        StructField("source", ArrayType(
            StructType([
                StructField("@id", StringType(), True),
                StructField("iHash", StringType(), True)
            ])
        ))
    ])
)

expanded_df = parsed_df.select(
    from_json(col("jsonData.subject"), id_schema).getField("@id").alias("subject"),
    from_json(col("jsonData.predicate"), id_schema).getField("@id").alias("predicate"),
    from_json(col("jsonData.objects"), object_schema).alias("objects")
)

flat_df = expanded_df \
    .withColumn("object", explode(col("objects"))) \
    .select(
        "subject",
        "predicate",
        col("object.object.@value").alias("value"),
        col("object.object.@type").alias("value_type"),
        col("object.source.@id").alias("source_id"),
        col("object.source.iHash").alias("source_iHash")
    )

flat_df.repartition(1).write.mode("overwrite").parquet("allDataParquet")
# Out:
# Starting Spark Session...
# Spark Session started.
# JSON files read successfully.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql.functions import col, explode, regexp_extract, when, concat_ws
import os
import sys
from glob import glob

schema = StructType([
    StructField("subject", StringType(), True),
    StructField("predicate", StringType(), True),
    StructField("object", StringType(), True),
    StructField("jsonrow", StringType(), True)
])
os.environ["JAVA_HOME"] = "/local/d1/users/kv21supo/micromamba/envs/jupyter"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
sys.stdout.flush()

print("Starting Spark Session...")
spark = SparkSession.builder \
    .appName("Data Exploration") \
    .config("spark.driver.memory", "100g") \
    .config("spark.executor.cores", "72") \
    .config("spark.sql.shuffle.partitions", "72") \
    .config("spark.ui.enabled", "false") \
    .getOrCreate()
print("Spark Session started.")
print("Reading Parquet files...")

folderPath = "allDataParquet/"
filePaths = glob(os.path.join(folderPath, "*.parquet"))

dfRaw = spark.read.parquet(*filePaths)

print("Parquet files read successfully.")

flat_df_with_lang = dfRaw \
    .withColumn("source_id", explode(col("source_id"))) \
    .withColumn("lang", regexp_extract(col("source_id"), r"lang=([a-z]+)", 1))

# Step 1: Filter for predicates starting with dbpedia ontology
ontology_predicates_df = flat_df_with_lang.filter(
    (col("predicate").contains("dbpedia.org")) | (col("subject").contains("dbpedia"))
)

# Step 2: Filter for language conditions
filtered_df = ontology_predicates_df.filter(
    (col("lang") == "en") | (col("lang") == "") | (col("lang") == "commons") | (col("lang").isNull()) | (col("lang") == "simple") | (col("lang") == "new") | (col("lang") == "redirected") | (col("lang") == "batsmg")
)


fused_df = filtered_df.withColumn(
    "object",
    when(
        (col("value").isNull()) & (col("value_type").isNull()),
        None
    ).otherwise(concat_ws(":", col("value"), col("value_type")))
).select("subject", "predicate", "object") 

fused_df.repartition(1).write.mode("overwrite").parquet("dbpediaOntologyROWS")
# Out:
# Starting Spark Session...
# Spark Session started.
# Reading Parquet files...
# Parquet files read successfully.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql.functions import col, explode, regexp_extract, when, concat_ws
import os
import sys
from glob import glob

schema = StructType([
    StructField("subject", StringType(), True),
    StructField("predicate", StringType(), True),
    StructField("object", StringType(), True),
    StructField("jsonrow", StringType(), True)
])
os.environ["JAVA_HOME"] = "/local/d1/users/kv21supo/micromamba/envs/jupyter"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
sys.stdout.flush()

print("Starting Spark Session...")
spark = SparkSession.builder \
    .appName("Data Exploration") \
    .config("spark.driver.memory", "100g") \
    .config("spark.executor.cores", "72") \
    .config("spark.sql.shuffle.partitions", "72") \
    .config("spark.ui.enabled", "false") \
    .getOrCreate()
print("Spark Session started.")
print("Reading Parquet files...")

folderPath = "dbpediaOntologyROWS/"
filePaths = glob(os.path.join(folderPath, "*.parquet"))

dfRaw = spark.read.parquet(*filePaths)

print("Parquet files read successfully.")
# Out:
# Starting Spark Session...
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/09/18 20:37:41 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Spark Session started.
# Reading Parquet files...
# Parquet files read successfully.

# %% [markdown]
# # Presidents Query FAILED #

# %%
peopleWithActiveYears = dfRaw.filter(col("predicate") == "http://dbpedia.org/ontology/activeYearsStartDate").select("subject").distinct().collect()
presidents = dfRaw.filter(col("predicate").contains("president")).select("subject").distinct().collect()

print(f"People with activeYearsStartDate: {len(peopleWithActiveYears)}")
print(f"Presidents: {len(presidents)}")

for person in peopleWithActiveYears:
    if "4vVY3" in person["subject"] or "29HeC" in person["subject"] or "y533" in person["subject"] or "B6dR" in person["subject"]:
        print(person["subject"])
        
print("---------------------------------")

for president in presidents:
    if "bill" in president["subject"] or "29HeC" in president["subject"] or "y533" in president["subject"] or "B6dR" in president["subject"]:
        print(president["subject"])

# dfRaw.filter(col("subject") == "https://global.dbpedia.org/id/4vVY3").select("predicate").distinct().show(200, truncate=False)
orderInOffice = dfRaw.filter(col("predicate") == "http://dbpedia.org/ontology/orderInOffice").select("subject").distinct().collect()

for person in orderInOffice:
    if "4vVY3" in person["subject"] or "29HeC" in person["subject"] or "y533" in person["subject"] or "B6dR" in person["subject"] or "2DcKK" in person["subject"] or "3DCUj" in person["subject"]:
        print(person["subject"])

dfRaw.filter((col("subject") == "https://global.dbpedia.org/id/4vVY3") & (col("predicate") == "http://dbpedia.org/ontology/predecessor")).show(200, truncate=False)
# Out:
# People with activeYearsStartDate: 123201
# Presidents: 14990
# https://global.dbpedia.org/id/129HeC
# https://global.dbpedia.org/id/1y533
# https://global.dbpedia.org/id/4vVY3
# ---------------------------------
# https://global.dbpedia.org/id/12DcKK
# https://global.dbpedia.org/id/3DCUj
# https://global.dbpedia.org/id/1y533
# https://global.dbpedia.org/id/B6dR
# https://global.dbpedia.org/id/4vVY3
# https://global.dbpedia.org/id/129HeC
# [Stage 220:===================================================>   (44 + 3) / 47]
# +-------+---------+------+
# |subject|predicate|object|
# +-------+---------+------+
# +-------+---------+------+

# %%
dfRaw.filter(col("subject") == "https://global.dbpedia.org/id/4n8e5").show(200, truncate=False)
# Out:
# [Stage 51:===================================================>    (33 + 3) / 36]
# +-----------------------------------+------------------------------------------------------------+----------------------------------------------------------------------------+
# |subject                            |predicate                                                   |object                                                                      |
# +-----------------------------------+------------------------------------------------------------+----------------------------------------------------------------------------+
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/1999/02/22-rdf-syntax-ns#type             |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/1999/02/22-rdf-syntax-ns#type             |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/1999/02/22-rdf-syntax-ns#type             |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/1999/02/22-rdf-syntax-ns#type             |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2003/01/geo/wgs84_pos#long                |-73.94:http://www.w3.org/2001/XMLSchema#float                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2003/01/geo/wgs84_pos#long                |-73.94:http://www.w3.org/2001/XMLSchema#float                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2003/01/geo/wgs84_pos#long                |-74.0059:http://www.w3.org/2001/XMLSchema#float                             |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2003/01/geo/wgs84_pos#long                |-74.0059:http://www.w3.org/2001/XMLSchema#float                             |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2003/01/geo/wgs84_pos#lat                 |40.7127:http://www.w3.org/2001/XMLSchema#float                              |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2003/01/geo/wgs84_pos#lat                 |40.7127:http://www.w3.org/2001/XMLSchema#float                              |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2003/01/geo/wgs84_pos#lat                 |40.67:http://www.w3.org/2001/XMLSchema#float                                |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2003/01/geo/wgs84_pos#lat                 |40.67:http://www.w3.org/2001/XMLSchema#float                                |
# |https://global.dbpedia.org/id/4n8e5|http://www.georss.org/georss/point                          |40.7127 -74.0059:http://www.w3.org/2001/XMLSchema#string                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.georss.org/georss/point                          |40.7127 -74.0059:http://www.w3.org/2001/XMLSchema#string                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.georss.org/georss/point                          |40.67 -73.94:http://www.w3.org/2001/XMLSchema#string                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.georss.org/georss/point                          |40.67 -73.94:http://www.w3.org/2001/XMLSchema#string                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/PopulatedPlace/areaTotal        |1213.3679898826506:http://dbpedia.org/datatype/squareKilometre              |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/PopulatedPlace/populationDensity|3329242.3102596314:http://dbpedia.org/datatype/inhabitantsPerSquareKilometre|
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/PopulatedPlace/areaMetro        |34493.46165345485:http://dbpedia.org/datatype/squareKilometre               |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/areaMetro                       |3.449346165345485E10:http://www.w3.org/2001/XMLSchema#double                |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/populationTotal                 |8537673:http://www.w3.org/2001/XMLSchema#nonNegativeInteger                 |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/populationTotal                 |8175133:http://www.w3.org/2001/XMLSchema#nonNegativeInteger                 |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/areaTotal                       |1.2133679898826506E9:http://www.w3.org/2001/XMLSchema#double                |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/elevation                       |10.0584:http://www.w3.org/2001/XMLSchema#double                             |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/elevation                       |10.0:http://www.w3.org/2001/XMLSchema#double                                |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/areaWater                       |4.2952621820623255E8:http://www.w3.org/2001/XMLSchema#double                |
# |https://global.dbpedia.org/id/4n8e5|http://xmlns.com/foaf/0.1/nick                              |SeeNicknames of New York City                                               |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/areaCode                        |929:http://www.w3.org/2001/XMLSchema#string                                 |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/areaCode                        |212/646/332,718/347/929,917:http://www.w3.org/2001/XMLSchema#string         |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/areaCode                        |212:http://www.w3.org/2001/XMLSchema#string                                 |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/areaCode                        |347:http://www.w3.org/2001/XMLSchema#string                                 |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/areaCode                        |718:http://www.w3.org/2001/XMLSchema#string                                 |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/areaCode                        |646:http://www.w3.org/2001/XMLSchema#string                                 |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/areaCode                        |917:http://www.w3.org/2001/XMLSchema#string                                 |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/demonym                         |New Yorker                                                                  |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/areaLand                        |7.838417716764181E8:http://www.w3.org/2001/XMLSchema#double                 |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/formationDate                   |1624-1-1:http://www.w3.org/2001/XMLSchema#date                              |
# |https://global.dbpedia.org/id/4n8e5|http://xmlns.com/foaf/0.1/name                              |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://xmlns.com/foaf/0.1/name                              |City of New York                                                            |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/populationTotalRanking          |1:http://www.w3.org/2001/XMLSchema#positiveInteger                          |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/populationDensity               |3329242.3102596314:http://www.w3.org/2001/XMLSchema#double                  |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/iataLocationIdentifier          |NYC:http://www.w3.org/2001/XMLSchema#string                                 |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/zipCode                         |100009:http://www.w3.org/2001/XMLSchema#string                              |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/zipCode                         |116009:http://www.w3.org/2001/XMLSchema#string                              |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/zipCode                         |111009:http://www.w3.org/2001/XMLSchema#string                              |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/zipCode                         |110045:http://www.w3.org/2001/XMLSchema#string                              |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/postalCode                      |100xxxx, 11004, 111xxxx, 116xx:http://www.w3.org/2001/XMLSchema#string      |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/emblem                          |Seal of New York City.svg:http://www.w3.org/2001/XMLSchema#string           |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/utcOffset                       |:00:http://www.w3.org/2001/XMLSchema#string                                 |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/unloCode                        |USNYC:http://www.w3.org/2001/XMLSchema#string                               |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/follows                         |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/follows                         |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/namedAfter                      |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/namedAfter                      |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/namedAfter                      |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/namedAfter                      |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/namedAfter                      |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://xmlns.com/foaf/0.1/homepage                          |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/country                         |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/country                         |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/country                         |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/primeMinister                   |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/primeMinister                   |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/governmentType                  |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/politicalLeader                 |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/city                            |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/city                            |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/subdivision                     |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/subdivision                     |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/subdivision                     |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/subdivision                     |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/subdivision                     |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/subdivision                     |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/subdivision                     |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/subdivision                     |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#seeAlso                |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/timeZone                        |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/type                            |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/coatOfArms                      |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/coatOfArms                      |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://dbpedia.org/ontology/governingBody                   |NULL                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Táva Nueva York                                                             |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Нью Йорк хото                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Nova York                                                                   |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Нью-Йорк                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Nyu York Shehiri                                                            |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Nju Jork                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Novjorko                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Thành phố New York                                                          |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Nua-Eabhrac                                                                 |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |نیویورک                                                                     |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Nouvieau York                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Нью-Йорк                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Нью-Йорк                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York Ceety                                                              |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |ᓂᐅ ᐃᐅᕐᒃ ᓯᑎ                                                                  |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |뉴욕                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Nueva York                                                                  |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |نیویارک شہر                                                                 |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Нью Йорк балһсн                                                             |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Нью-Йорк                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Ню Йорк                                                                     |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |نيويارک                                                                     |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York Lakanbalen                                                         |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Њујорк                                                                      |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Nueva York                                                                  |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |نيؤيؤرک                                                                     |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Niū-iók-chê                                                                 |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Нью-Йорк                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Nueva York                                                                  |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |নিউয়ৰ্ক মহানগৰ                                                             |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Caayr York Noa                                                              |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Niu York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Novum Eboracum                                                              |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Niu Ioka                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |紐約                                                                        |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Nova Iorque                                                                 |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Kuta New York                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Nueva York                                                                  |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |ന്യൂയോർക്ക് നഗരം                                                            |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Nowy Jork                                                                   |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |نیویورک‌                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Niujorkas                                                                   |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |న్యూయార్క్                                                                  |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |न्यूयॉर्क नगर                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |न्युयोर्क सहर                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Tchiaq York Iniqpak                                                         |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |纽约市                                                                      |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Lungsod ng New York                                                         |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Néu-yok-sṳ                                                                  |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Niu Yok Siti                                                                |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Нью-Йорк                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Нью-Йорк                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |ទីក្រុងញូវយ៉ក                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |ኒው ዮርክ ከተማ                                                                  |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Niujyoz                                                                     |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York City                                                               |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Њујорк                                                                      |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Nova York                                                                   |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Nyu york                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |نیویۆرک                                                                     |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |Нью-Йорк                                                                    |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |ニューヨーク                                                                |
# |https://global.dbpedia.org/id/4n8e5|http://www.w3.org/2000/01/rdf-schema#label                  |New York                                                                    |
# +-----------------------------------+------------------------------------------------------------+----------------------------------------------------------------------------+
# only showing top 200 rows

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number
from pyspark.sql.functions import count
from pyspark.sql.functions import split

# Assuming dfRaw is already loaded and SparkSession is initialized

# Get cities
cities_df = dfRaw.filter(col("predicate") == "http://dbpedia.org/ontology/city") \
                 .select("subject") \
                 .distinct()

# Get population info
population_df = dfRaw.filter(col("predicate") == "http://dbpedia.org/ontology/populationTotal") \
                     .select("subject", "object") \
                     .withColumnRenamed("object", "population")

# Get population density info (replace with your correct predicate)
density_df = dfRaw.filter(col("predicate") == "http://dbpedia.org/ontology/PopulatedPlace/populationDensity") \
                  .select("subject", "object") \
                  .withColumnRenamed("object", "density")

# Join cities with population and density
result_df = cities_df.join(population_df, on="subject", how="left") \
                     .join(density_df, on="subject", how="left")

# Ensure unique population and density per subject (taking the first occurrence)
window_spec = Window.partitionBy("subject").orderBy("population", "density")
result_df_unique = result_df.withColumn("row_num", row_number().over(window_spec)) \
                            .filter(col("row_num") == 1) \
                            .drop("row_num")

# Get all labels for each subject
labels_df = dfRaw.filter(col("predicate") == "http://www.w3.org/2000/01/rdf-schema#label") \
                 .select("subject", "object") \
                 .withColumnRenamed("object", "label")

# Count occurrences of each label per subject
label_counts = labels_df.groupBy("subject", "label").agg(count("*").alias("label_count"))

# Get the most common label per subject
label_window = Window.partitionBy("subject").orderBy(col("label_count").desc())
most_common_labels = label_counts.withColumn("rn", row_number().over(label_window)) \
                                .filter(col("rn") == 1) \
                                .drop("label_count", "rn")

# Join with result_df_unique and clean population and density
resultWithLabel = result_df_unique.join(most_common_labels, on="subject", how="left") \
                                 .select(
                                     "subject",
                                     col("label"),
                                     regexp_extract(col("population"), r"(\d+)", 1).alias("total_population"),
                                     regexp_extract(col("density"), r"(\d+)", 1).alias("population_density")
                                 ).collect()

# resultWithLabel is the final DataFrame

# %%
i = 1
for row in resultWithLabel:
    if row["total_population"] is None or row["population_density"] is None:
        continue
    if int(row["total_population"]) > 5000000 and int(row["population_density"]) > 2000:
        print(row)
        i += 1
print(f"Total cities with population > 5,000,000: {i-1}")
# Out:
# Row(subject='https://global.dbpedia.org/id/1nhqh', label='Dhaka', total_population='12043977', population_density='8200')
# Row(subject='https://global.dbpedia.org/id/1o4jN', label='Ho Chi Minh City', total_population='10380000', population_density='4097')
# Row(subject='https://global.dbpedia.org/id/4ewfZ', label='Union County', total_population='536499563892', population_density='2086')
# Row(subject='https://global.dbpedia.org/id/4z941', label='London', total_population='8787892', population_density='5590')
# Row(subject='https://global.dbpedia.org/id/Gwvb', label='Osaka', total_population='8819416', population_density='4629')
# Row(subject='https://global.dbpedia.org/id/3MisF', label='Jakarta', total_population='10075310', population_density='14464')
# Row(subject='https://global.dbpedia.org/id/4qZeD', label='Санкт-Петербург', total_population='5351935', population_density='3699')
# Row(subject='https://global.dbpedia.org/id/3LZos', label='Teheran', total_population='8846782', population_density='11800')
# Row(subject='https://global.dbpedia.org/id/Vpeq', label='Tokyo', total_population='13784212', population_density='6224')
# Row(subject='https://global.dbpedia.org/id/12LqRP', label='Hyderabad Metropolitan Region', total_population='7749334', population_density='10477')
# Row(subject='https://global.dbpedia.org/id/2rYsW', label='Tokyo', total_population='9375104', population_density='15146')
# Row(subject='https://global.dbpedia.org/id/4k4dt', label='Netherlands', total_population='17000000', population_density='41526')
# Row(subject='https://global.dbpedia.org/id/4n8e5', label='New York', total_population='8175133', population_density='3329242')
# Row(subject='https://global.dbpedia.org/id/3m9os', label='Istanbul', total_population='14657434', population_density='7664')
# Row(subject='https://global.dbpedia.org/id/52Xp5', label='Lagos', total_population='21324000', population_density='6871')
# Row(subject='https://global.dbpedia.org/id/N1oi', label='Dhaka', total_population='14399000', population_density='46997')
# Row(subject='https://global.dbpedia.org/id/4YHwc', label='Hudson County', total_population='634266691643', population_density='5781')
# Row(subject='https://global.dbpedia.org/id/JDQd', label='Kanagawa', total_population='9098984', population_density='3770')
# Row(subject='https://global.dbpedia.org/id/NL8K', label='Hyderabad', total_population='6809970', population_density='10477')
# Row(subject='https://global.dbpedia.org/id/52ZqS', label='Hong Kong', total_population='7336585', population_density='6573')
# Row(subject='https://global.dbpedia.org/id/AE79', label='Cook County', total_population='5194675', population_density='2128')
# Row(subject='https://global.dbpedia.org/id/JyeH', label='Essex County', total_population='783969808285', population_density='2439')
# Row(subject='https://global.dbpedia.org/id/MsEi', label='Delhi', total_population='16787941', population_density='11312')
# Row(subject='https://global.dbpedia.org/id/hYK6', label='São Paulo', total_population='12106920', population_density='8959')
# Row(subject='https://global.dbpedia.org/id/2fvNK', label='Santiago', total_population='6123491', population_density='9820')
# Total cities with population > 5,000,000: 25

# %%
from pyspark.sql.functions import countDistinct

# Assuming dfRaw is already loaded and SparkSession is initialized

# Step 1: Get distinct cities
cities_df = dfRaw.filter(col("predicate") == "http://dbpedia.org/ontology/city") \
                 .select("subject") \
                 .distinct()

# Step 2: Count distinct predicates per subject
predicate_counts = dfRaw.groupBy("subject") \
                       .agg(countDistinct("predicate").alias("predicate_count"))

# Step 3: Filter for cities with more than 35 unique predicates
city_predicate_counts = cities_df.join(predicate_counts, on="subject", how="inner") \
                                 .filter(col("predicate_count") > 35) \
                                 .select("subject", "predicate_count") \
                                 .distinct()

# Step 4: Get predicates for these cities
city_predicates = dfRaw.join(city_predicate_counts, on="subject", how="inner") \
                       .select("subject", "predicate") \
                       .distinct()

# Step 5: Count how many cities each predicate appears in
predicate_city_counts = city_predicates.groupBy("predicate") \
                                      .agg(countDistinct("subject").alias("city_count"))

# Step 6: Get the total number of cities with >35 predicates
total_cities = city_predicate_counts.count()

# Step 7: Filter for predicates that appear in all such cities
common_predicates = predicate_city_counts.filter(col("city_count") == total_cities) \
                                        .select("predicate")

# Step 8: Get labels for the cities
labels_df = dfRaw.filter(col("predicate") == "http://www.w3.org/2000/01/rdf-schema#label") \
                 .select("subject", "object") \
                 .withColumnRenamed("object", "label")

# Count occurrences of each label per subject
label_counts = labels_df.groupBy("subject", "label").agg(count("*").alias("label_count"))

# Get the most common label per subject
label_window = Window.partitionBy("subject").orderBy(col("label_count").desc())
most_common_labels = label_counts.withColumn("rn", row_number().over(label_window)) \
                                .filter(col("rn") == 1) \
                                .select("subject", "label")

# Step 9: Join cities with their predicate counts and labels
result_df = city_predicate_counts.join(most_common_labels, on="subject", how="left") \
                                .select(
                                    col("subject"),
                                    col("label"),
                                    col("predicate_count")
                                ) \
                                .distinct() \
                                .orderBy(col("predicate_count").desc())

# Step 10: Collect common predicates as a list for reference
common_predicates_list = [row["predicate"] for row in common_predicates.collect()]

# Output the results
print("Cities with more than 35 unique predicates:")
result_df.show(300, truncate=False)
print("Common predicates across these cities:", common_predicates_list)
# Out:
# Cities with more than 35 unique predicates:
# [Stage 165:==========================================>           (56 + 16) / 72]
# +------------------------------------+-------------+---------------+
# |subject                             |label        |predicate_count|
# +------------------------------------+-------------+---------------+
# |https://global.dbpedia.org/id/KZb4  |Chicago      |51             |
# |https://global.dbpedia.org/id/38Nvt |Montreal     |47             |
# |https://global.dbpedia.org/id/S6yW  |Allentown    |46             |
# |https://global.dbpedia.org/id/6T27  |Boston       |46             |
# |https://global.dbpedia.org/id/Q5rP  |Sherbrooke   |46             |
# |https://global.dbpedia.org/id/4obdh |San Francisco|46             |
# |https://global.dbpedia.org/id/2dVXG |Lincoln      |45             |
# |https://global.dbpedia.org/id/MaJu  |Pittsburgh   |44             |
# |https://global.dbpedia.org/id/12Dp4j|Atlanta      |44             |
# |https://global.dbpedia.org/id/e7ew  |San Jose     |43             |
# |https://global.dbpedia.org/id/hYK6  |São Paulo    |43             |
# |https://global.dbpedia.org/id/4iE6U |Seattle      |43             |
# |https://global.dbpedia.org/id/39A3U |Thunder Bay  |43             |
# |https://global.dbpedia.org/id/dzU6  |San Diego    |42             |
# |https://global.dbpedia.org/id/dfNY  |Denver       |42             |
# |https://global.dbpedia.org/id/dHKQ  |Dallas       |42             |
# |https://global.dbpedia.org/id/4pwNN |Los Angeles  |42             |
# |https://global.dbpedia.org/id/HvBH  |Detroit      |42             |
# |https://global.dbpedia.org/id/121nnL|Charlottetown|42             |
# |https://global.dbpedia.org/id/4a617 |Bakersfield  |42             |
# +------------------------------------+-------------+---------------+
# only showing top 20 rows
# Common predicates across these cities: ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2003/01/geo/wgs84_pos#lat', 'http://dbpedia.org/ontology/city', 'http://www.georss.org/georss/point', 'http://dbpedia.org/ontology/country', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2003/01/geo/wgs84_pos#long', 'http://www.w3.org/2000/01/rdf-schema#seeAlso']

# %%
subjects_df = dfRaw.filter(col("predicate").contains("office")) \
                   .filter(col("object").contains("President of the United States")) \
                   .filter(col("object").contains("United States")) \
                   .select("subject") \
                   .distinct()

# Step 2: Get all labels for these subjects
labels_df = dfRaw.filter(col("predicate") == "http://www.w3.org/2000/01/rdf-schema#label") \
                 .select("subject", "object") \
                 .withColumnRenamed("object", "label")

# Step 3: Count occurrences of each label per subject
label_counts = labels_df.join(subjects_df, on="subject", how="inner") \
                       .groupBy("subject", "label") \
                       .agg(count("*").alias("label_count"))

# Step 4: Get the most common label per subject
label_window = Window.partitionBy("subject").orderBy(col("label_count").desc())
most_common_labels = label_counts.withColumn("rn", row_number().over(label_window)) \
                                .filter(col("rn") == 1) \
                                .select("subject", "label") \
                                .distinct()

# Step 5: Final result
result_df = most_common_labels.orderBy("subject") \
                             .select("subject", "label")

# Show up to 200 rows without truncation
result_df.show(200, truncate=False)
# Out:
# [Stage 223:================================================>      (64 + 8) / 72]
# +----------------------------------------------------+-----------------------------------------------------+
# |subject                                             |label                                                |
# +----------------------------------------------------+-----------------------------------------------------+
# |http://dbpedia.org/resource/Rafael_Nú༞z_(politician)|Rafael Nú༞z (politician)                             |
# |https://global.dbpedia.org/id/125e9x                |Elbridge Gerry                                       |
# |https://global.dbpedia.org/id/127Ror                |Daniel D. Tompkins                                   |
# |https://global.dbpedia.org/id/1299go                |Gustavus Town Kirby                                  |
# |https://global.dbpedia.org/id/12AtKZ                |George Washington                                    |
# |https://global.dbpedia.org/id/12DcKK                |George H. W. Bush                                    |
# |https://global.dbpedia.org/id/12EpJE                |Jimmy Carter                                         |
# |https://global.dbpedia.org/id/12HqF2                |Mike Pence                                           |
# |https://global.dbpedia.org/id/12NP2r                |Henry A. Wallace                                     |
# |https://global.dbpedia.org/id/1kEbj                 |Aaron Burr                                           |
# |https://global.dbpedia.org/id/1mcn9                 |Charles G. Dawes                                     |
# |https://global.dbpedia.org/id/1tPEg                 |Al Gore                                              |
# |https://global.dbpedia.org/id/1v57g                 |George Clinton                                       |
# |https://global.dbpedia.org/id/1vcV1                 |Spiro Agnew                                          |
# |https://global.dbpedia.org/id/1yDio                 |John C. Calhoun                                      |
# |https://global.dbpedia.org/id/2Y6DK                 |Charles Curtis                                       |
# |https://global.dbpedia.org/id/2Z1w3                 |Hannibal Hamlin                                      |
# |https://global.dbpedia.org/id/2Z2e5                 |John C. Breckinridge                                 |
# |https://global.dbpedia.org/id/2Z5zM                 |Alben W. Barkley                                     |
# |https://global.dbpedia.org/id/2mt39                 |William R. King                                      |
# |https://global.dbpedia.org/id/2t1Jg                 |Adlai Stevenson I                                    |
# |https://global.dbpedia.org/id/2t8aJ                 |George M. Dallas                                     |
# |https://global.dbpedia.org/id/2tG34                 |James S. Sherman                                     |
# |https://global.dbpedia.org/id/2uN9K                 |Tomás Cipriano de Mosquera                           |
# |https://global.dbpedia.org/id/37ESf                 |Theodore Roosevelt                                   |
# |https://global.dbpedia.org/id/3AMic                 |Woodrow Wilson                                       |
# |https://global.dbpedia.org/id/3C6Qj                 |James A. Garfield                                    |
# |https://global.dbpedia.org/id/3E5hu                 |William McKinley                                     |
# |https://global.dbpedia.org/id/3F36c                 |Grover Cleveland                                     |
# |https://global.dbpedia.org/id/3FJhb                 |Warren G. Harding                                    |
# |https://global.dbpedia.org/id/3FKYg                 |Herbert Hoover                                       |
# |https://global.dbpedia.org/id/3GtSY                 |Chester A. Arthur                                    |
# |https://global.dbpedia.org/id/3HVyo                 |Benjamin Harrison                                    |
# |https://global.dbpedia.org/id/3Hyz1                 |Rutherford B. Hayes                                  |
# |https://global.dbpedia.org/id/3J16r                 |William Howard Taft                                  |
# |https://global.dbpedia.org/id/3KXoH                 |Calvin Coolidge                                      |
# |https://global.dbpedia.org/id/3yrSo                 |World tour of Ulysses S. Grant                       |
# |https://global.dbpedia.org/id/4LJvP                 |Abraham Lincoln and slavery                          |
# |https://global.dbpedia.org/id/4UaQ8                 |Dick Cheney                                          |
# |https://global.dbpedia.org/id/4ZTc7                 |Dan Quayle                                           |
# |https://global.dbpedia.org/id/4ZVcm                 |Walter Mondale                                       |
# |https://global.dbpedia.org/id/4j76J                 |Early life and career of Thomas Jefferson            |
# |https://global.dbpedia.org/id/4kBNj                 |Grantism                                             |
# |https://global.dbpedia.org/id/4oPJd                 |Jefferson–Hemings controversy                        |
# |https://global.dbpedia.org/id/4pEL3                 |Joe Biden                                            |
# |https://global.dbpedia.org/id/4rfzt                 |Mike Donilon                                         |
# |https://global.dbpedia.org/id/4riCb                 |Morgan Mason                                         |
# |https://global.dbpedia.org/id/4w9Hm                 |Tony Blinken                                         |
# |https://global.dbpedia.org/id/4wTNT                 |Ulysses S. Grant and the American Civil War          |
# |https://global.dbpedia.org/id/4wdaw                 |Ulysses S. Grant presidential administration scandals|
# |https://global.dbpedia.org/id/4x8DR                 |Franklin Delano Roosevelt                            |
# |https://global.dbpedia.org/id/51mUj                 |Andrew Johnson                                       |
# |https://global.dbpedia.org/id/54Jk9                 |Abraham Lincoln                                      |
# |https://global.dbpedia.org/id/56Z6F                 |Lyndon B. Johnson                                    |
# |https://global.dbpedia.org/id/56fEx                 |Gerald Ford                                          |
# |https://global.dbpedia.org/id/56nDs                 |Richard Nixon                                        |
# |https://global.dbpedia.org/id/56odt                 |John F. Kennedy                                      |
# |https://global.dbpedia.org/id/57h75                 |Dwight D. Eisenhower                                 |
# |https://global.dbpedia.org/id/6PQ9v                 |Craig L. Fuller                                      |
# |https://global.dbpedia.org/id/6s3H2                 |Post-presidency of George Washington                 |
# |https://global.dbpedia.org/id/75smj                 |Colin Kahl                                           |
# |https://global.dbpedia.org/id/87n1k                 |Andrea Thompson                                      |
# |https://global.dbpedia.org/id/A9yf                  |Richard Mentor Johnson                               |
# |https://global.dbpedia.org/id/BPR5                  |Nelson Rockefeller                                   |
# |https://global.dbpedia.org/id/Chc7                  |Harry S. Truman                                      |
# |https://global.dbpedia.org/id/DeRC                  |Martin Van Buren                                     |
# |https://global.dbpedia.org/id/DmoJ                  |Thomas Jefferson                                     |
# |https://global.dbpedia.org/id/Dorr                  |John Quincy Adams                                    |
# |https://global.dbpedia.org/id/Dr9E                  |James Monroe                                         |
# |https://global.dbpedia.org/id/E5F7                  |John Adams                                           |
# |https://global.dbpedia.org/id/E6QS                  |James Madison                                        |
# |https://global.dbpedia.org/id/E6QT                  |Andrew Jackson                                       |
# |https://global.dbpedia.org/id/EYuX                  |James K. Polk                                        |
# |https://global.dbpedia.org/id/EaGe                  |William Henry Harrison                               |
# |https://global.dbpedia.org/id/EoUX                  |John Tyler                                           |
# |https://global.dbpedia.org/id/FGeR                  |Zachary Taylor                                       |
# |https://global.dbpedia.org/id/GUbG                  |Millard Fillmore                                     |
# |https://global.dbpedia.org/id/GosV                  |James Buchanan                                       |
# |https://global.dbpedia.org/id/GqBK                  |Franklin Pierce                                      |
# |https://global.dbpedia.org/id/dhox                  |Jake Sullivan                                        |
# |https://global.dbpedia.org/id/fPPa                  |Non-importation Act                                  |
# |https://global.dbpedia.org/id/fUbK                  |Bibliography of Ulysses S. Grant                     |
# |https://global.dbpedia.org/id/fcDS                  |Post-presidency of Ulysses S. Grant                  |
# |https://global.dbpedia.org/id/ffc3                  |Early life and career of Ulysses S. Grant            |
# |https://global.dbpedia.org/id/fjVn                  |Ulysses S. Grant presidential administration reforms |
# +----------------------------------------------------+-----------------------------------------------------+

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# Assuming dfRaw is already loaded and SparkSession is initialized

# Define filter conditions
is_office = F.lower(F.col("predicate")) == "http://dbpedia.org/ontology/office"
has_potus = F.lower(F.col("object")).rlike(r"president[\s-]of[\s-]the[\s-]united[\s-]states:")
not_vice = ~F.lower(F.col("object")).rlike(r"vice[\s-]*president")

# Step 1: Filter for presidents
presidents = (
    dfRaw
    .filter(is_office & has_potus & not_vice)
    .select("subject", "predicate", "object")
    .distinct()
    .filter(col("subject").contains("global.dbpedia.org/id/"))
)

# Step 2: Get distinct subjects
president_subjects = presidents.select("subject").distinct()

# Step 3: Get labels for these subjects
labels_df = dfRaw.filter(F.col("predicate") == "http://www.w3.org/2000/01/rdf-schema#label") \
                 .select("subject", "object") \
                 .withColumnRenamed("object", "label")

# Count occurrences of each label
label_counts = labels_df.join(president_subjects, on="subject", how="inner") \
                       .groupBy("subject", "label") \
                       .agg(F.count("*").alias("label_count"))

# Get the most common label per subject
label_window = Window.partitionBy("subject").orderBy(F.col("label_count").desc())
most_common_labels = label_counts.withColumn("rn", F.row_number().over(label_window)) \
                                .filter(F.col("rn") == 1) \
                                .select("subject", "label") \
                                .distinct()

# Step 4: Get termStart for these subjects
# Assuming termStart is under predicate "http://dbpedia.org/ontology/activeYearsStartDate"
term_start_df = dfRaw.filter(F.col("predicate").contains("years")) \
                     .select(
                         "subject",
                         F.regexp_extract(F.col("object"), r"(\d{4}-\d{2}-\d{2})", 1).alias("termStart")
                     ) \
                     .withColumn(
                         "termStart",
                         F.when(
                             F.col("termStart").cast("date").isNotNull(),
                             F.to_date(F.col("termStart"), "yyyy-MM-dd")
                         ).otherwise(None)  # Return NULL for invalid dates
                     )

# Step 5: Join labels and termStart
result_df = most_common_labels.join(term_start_df, on="subject", how="left") \
                             .select(
                                 F.col("subject"),
                                 F.col("label"),
                                 F.col("termStart")
                             ) \
                             .distinct() \
                             .orderBy(F.col("termStart").asc_nulls_last())  # Sort by termStart, nulls last

# Show the results
print("Presidents with their most common labels and term start dates:")
result_df.show(2000, truncate=False)

# Optionally, show the original presidents DataFrame for reference
print("Presidents with office predicate:")
presidents.show(2000, truncate=False)
# Out:
# Presidents with their most common labels and term start dates:
# +------------------------------------+-----------------------------------------------------+---------+
# |subject                             |label                                                |termStart|
# +------------------------------------+-----------------------------------------------------+---------+
# |https://global.dbpedia.org/id/4wdaw |Ulysses S. Grant presidential administration scandals|NULL     |
# |https://global.dbpedia.org/id/GqBK  |Franklin Pierce                                      |NULL     |
# |https://global.dbpedia.org/id/3Hyz1 |Rutherford B. Hayes                                  |NULL     |
# |https://global.dbpedia.org/id/Chc7  |Harry S. Truman                                      |NULL     |
# |https://global.dbpedia.org/id/E6QS  |James Madison                                        |NULL     |
# |https://global.dbpedia.org/id/51mUj |Andrew Johnson                                       |NULL     |
# |https://global.dbpedia.org/id/3FKYg |Herbert Hoover                                       |NULL     |
# |https://global.dbpedia.org/id/GUbG  |Millard Fillmore                                     |NULL     |
# |https://global.dbpedia.org/id/3F36c |Grover Cleveland                                     |NULL     |
# |https://global.dbpedia.org/id/ffc3  |Early life and career of Ulysses S. Grant            |NULL     |
# |https://global.dbpedia.org/id/3KXoH |Calvin Coolidge                                      |NULL     |
# |https://global.dbpedia.org/id/57h75 |Dwight D. Eisenhower                                 |NULL     |
# |https://global.dbpedia.org/id/fjVn  |Ulysses S. Grant presidential administration reforms |NULL     |
# |https://global.dbpedia.org/id/12DcKK|George H. W. Bush                                    |NULL     |
# |https://global.dbpedia.org/id/Dorr  |John Quincy Adams                                    |NULL     |
# |https://global.dbpedia.org/id/4wTNT |Ulysses S. Grant and the American Civil War          |NULL     |
# |https://global.dbpedia.org/id/FGeR  |Zachary Taylor                                       |NULL     |
# |https://global.dbpedia.org/id/EaGe  |William Henry Harrison                               |NULL     |
# |https://global.dbpedia.org/id/3FJhb |Warren G. Harding                                    |NULL     |
# |https://global.dbpedia.org/id/4LJvP |Abraham Lincoln and slavery                          |NULL     |
# |https://global.dbpedia.org/id/E5F7  |John Adams                                           |NULL     |
# |https://global.dbpedia.org/id/3E5hu |William McKinley                                     |NULL     |
# |https://global.dbpedia.org/id/DeRC  |Martin Van Buren                                     |NULL     |
# |https://global.dbpedia.org/id/56nDs |Richard Nixon                                        |NULL     |
# |https://global.dbpedia.org/id/DmoJ  |Thomas Jefferson                                     |NULL     |
# |https://global.dbpedia.org/id/3J16r |William Howard Taft                                  |NULL     |
# |https://global.dbpedia.org/id/4x8DR |Franklin Delano Roosevelt                            |NULL     |
# |https://global.dbpedia.org/id/54Jk9 |Abraham Lincoln                                      |NULL     |
# |https://global.dbpedia.org/id/12EpJE|Jimmy Carter                                         |NULL     |
# |https://global.dbpedia.org/id/6s3H2 |Post-presidency of George Washington                 |NULL     |
# |https://global.dbpedia.org/id/4oPJd |Jefferson–Hemings controversy                        |NULL     |
# |https://global.dbpedia.org/id/4j76J |Early life and career of Thomas Jefferson            |NULL     |
# |https://global.dbpedia.org/id/56Z6F |Lyndon B. Johnson                                    |NULL     |
# |https://global.dbpedia.org/id/56fEx |Gerald Ford                                          |NULL     |
# |https://global.dbpedia.org/id/E6QT  |Andrew Jackson                                       |NULL     |
# |https://global.dbpedia.org/id/56odt |John F. Kennedy                                      |NULL     |
# |https://global.dbpedia.org/id/3yrSo |World tour of Ulysses S. Grant                       |NULL     |
# |https://global.dbpedia.org/id/3GtSY |Chester A. Arthur                                    |NULL     |
# |https://global.dbpedia.org/id/Dr9E  |James Monroe                                         |NULL     |
# |https://global.dbpedia.org/id/EYuX  |James K. Polk                                        |NULL     |
# |https://global.dbpedia.org/id/37ESf |Theodore Roosevelt                                   |NULL     |
# |https://global.dbpedia.org/id/12AtKZ|George Washington                                    |NULL     |
# |https://global.dbpedia.org/id/fPPa  |Non-importation Act                                  |NULL     |
# |https://global.dbpedia.org/id/3AMic |Woodrow Wilson                                       |NULL     |
# |https://global.dbpedia.org/id/fcDS  |Post-presidency of Ulysses S. Grant                  |NULL     |
# |https://global.dbpedia.org/id/3C6Qj |James A. Garfield                                    |NULL     |
# |https://global.dbpedia.org/id/3HVyo |Benjamin Harrison                                    |NULL     |
# |https://global.dbpedia.org/id/fUbK  |Bibliography of Ulysses S. Grant                     |NULL     |
# |https://global.dbpedia.org/id/4kBNj |Grantism                                             |NULL     |
# |https://global.dbpedia.org/id/GosV  |James Buchanan                                       |NULL     |
# |https://global.dbpedia.org/id/4riCb |Morgan Mason                                         |NULL     |
# +------------------------------------+-----------------------------------------------------+---------+
#
# Presidents with office predicate:
# [Stage 459:===================================================>   (67 + 5) / 72]
# +------------------------------------+----------------------------------+-----------------------------------------------------------------------------------------------+
# |subject                             |predicate                         |object                                                                                         |
# +------------------------------------+----------------------------------+-----------------------------------------------------------------------------------------------+
# |https://global.dbpedia.org/id/4wTNT |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/4j76J |http://dbpedia.org/ontology/office|3rdPresident of the United States:http://www.w3.org/2001/XMLSchema#string                      |
# |https://global.dbpedia.org/id/4oPJd |http://dbpedia.org/ontology/office|3rdPresident of the United States:http://www.w3.org/2001/XMLSchema#string                      |
# |https://global.dbpedia.org/id/54Jk9 |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/4kBNj |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/3yrSo |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/4x8DR |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/3E5hu |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/Dr9E  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/56odt |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/3Hyz1 |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/3FKYg |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/57h75 |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/DeRC  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/FGeR  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/GUbG  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/12EpJE|http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/Chc7  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/12DcKK|http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/4riCb |http://dbpedia.org/ontology/office|Special Assistant to the President of the United States:http://www.w3.org/2001/XMLSchema#string|
# |https://global.dbpedia.org/id/EaGe  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/E5F7  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/3F36c |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/3AMic |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/37ESf |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/GqBK  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/56fEx |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/E6QS  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/3GtSY |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/DmoJ  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/3KXoH |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/ffc3  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/56Z6F |http://dbpedia.org/ontology/office|36thPresident of the United States:http://www.w3.org/2001/XMLSchema#string                     |
# |https://global.dbpedia.org/id/3HVyo |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/6s3H2 |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/4LJvP |http://dbpedia.org/ontology/office|16th President of the United States:http://www.w3.org/2001/XMLSchema#string                    |
# |https://global.dbpedia.org/id/E6QT  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/3J16r |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/fPPa  |http://dbpedia.org/ontology/office|3rdPresident of the United States:http://www.w3.org/2001/XMLSchema#string                      |
# |https://global.dbpedia.org/id/51mUj |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/EYuX  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/3C6Qj |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/56nDs |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/fcDS  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/Dorr  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/12AtKZ|http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/fUbK  |http://dbpedia.org/ontology/office|18thPresident of the United States:http://www.w3.org/2001/XMLSchema#string                     |
# |https://global.dbpedia.org/id/fjVn  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/GosV  |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/3FJhb |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# |https://global.dbpedia.org/id/4wdaw |http://dbpedia.org/ontology/office|President of the United States:http://www.w3.org/2001/XMLSchema#string                         |
# +------------------------------------+----------------------------------+-----------------------------------------------------------------------------------------------+

# %%
# Assuming dfRaw is already loaded and SparkSession is initialized

# List of president IDs
presidentIds = [
    "https://global.dbpedia.org/id/4vVY3",
    "https://global.dbpedia.org/id/1y533",
    "https://global.dbpedia.org/id/B6dR",
    "https://global.dbpedia.org/id/3DCUj",
    "https://global.dbpedia.org/id/56odt",
    "https://global.dbpedia.org/id/4x8DR",
]

# Step 1: Filter dfRaw for the specified president IDs
president_predicates = dfRaw.filter(col("subject").isin(presidentIds)) \
                           .select("subject", "predicate") \
                           .distinct()

# Step 2: Count how many presidents each predicate appears for
predicate_counts = president_predicates.groupBy("predicate") \
                                      .agg(countDistinct("subject").alias("subject_count"))

# Step 3: Filter for predicates common to all presidents
total_presidents = len(presidentIds)
common_predicates = predicate_counts.filter(col("subject_count") == total_presidents) \
                                   .select("predicate")

# Step 4: Get labels for the presidents
labels_df = dfRaw.filter(col("predicate") == "http://www.w3.org/2000/01/rdf-schema#label") \
                 .filter(col("subject").isin(presidentIds)) \
                 .select("subject", "object") \
                 .withColumnRenamed("object", "label")

# Count occurrences of each label per subject
label_counts = labels_df.groupBy("subject", "label").agg(count("*").alias("label_count"))

# Get the most common label per subject
label_window = Window.partitionBy("subject").orderBy(col("label_count").desc())
most_common_labels = label_counts.withColumn("rn", row_number().over(label_window)) \
                                .filter(col("rn") == 1) \
                                .select("subject", "label")

# Step 5: Join common predicates with president labels for context
result_df = most_common_labels.orderBy("subject") \
                             .select("subject", "label")

# Step 6: Collect common predicates as a list
common_predicates_list = [row["predicate"] for row in common_predicates.collect()]

# Output the results
print("Presidents and their most common labels:")
result_df.show(len(presidentIds), truncate=False)
print("Common predicates across all specified presidents:", common_predicates_list)
# Out:
# Presidents and their most common labels:
# [Stage 398:======================================================>(71 + 1) / 72]
# +-----------------------------------+-------------------------+
# |subject                            |label                    |
# +-----------------------------------+-------------------------+
# |https://global.dbpedia.org/id/1y533|George W. Bush           |
# |https://global.dbpedia.org/id/3DCUj|Ulysses S. Grant         |
# |https://global.dbpedia.org/id/4vVY3|Barack Obama             |
# |https://global.dbpedia.org/id/4x8DR|Franklin Delano Roosevelt|
# |https://global.dbpedia.org/id/56odt|John F. Kennedy          |
# |https://global.dbpedia.org/id/B6dR |Bill Clinton             |
# +-----------------------------------+-------------------------+
#
# Common predicates across all specified presidents: ['http://dbpedia.org/ontology/birthName', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/ontology/birthDate', 'http://dbpedia.org/ontology/award', 'http://dbpedia.org/ontology/signature', 'http://dbpedia.org/ontology/orderInOffice', 'http://dbpedia.org/ontology/vicePresident', 'http://dbpedia.org/ontology/father', 'http://dbpedia.org/ontology/spouse', 'http://dbpedia.org/ontology/occupation', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://dbpedia.org/ontology/citizenship', 'http://dbpedia.org/ontology/almaMater', 'http://www.w3.org/2000/01/rdf-schema#seeAlso', 'http://dbpedia.org/ontology/successor', 'http://dbpedia.org/ontology/religion', 'http://dbpedia.org/ontology/child', 'http://dbpedia.org/ontology/birthPlace', 'http://dbpedia.org/ontology/party']

# %%
# List of predicates, with one entry as a list for OR condition
required_predicates = [
    'http://dbpedia.org/ontology/birthName',
    'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
    'http://dbpedia.org/ontology/birthDate',
    'http://dbpedia.org/ontology/signature',
    ['http://dbpedia.org/ontology/orderInOffice', 'http://dbpedia.org/ontology/order'],
    ['http://dbpedia.org/ontology/vicePresident', 'http://dbpedia.org/ontology/vicepresident'],
    'http://dbpedia.org/ontology/spouse',
    'http://dbpedia.org/ontology/occupation',
    'http://www.w3.org/2000/01/rdf-schema#label',
    'http://dbpedia.org/ontology/almaMater',
    'http://www.w3.org/2000/01/rdf-schema#seeAlso',
    'http://dbpedia.org/ontology/successor',
    'http://dbpedia.org/ontology/child',
    'http://dbpedia.org/ontology/birthPlace',
    'http://dbpedia.org/ontology/party',
    'http://dbpedia.org/ontology/office'
]

# Step 1: Filter subjects with all required predicates, handling OR condition
# Split predicates into single predicates and OR groups
single_predicates = [p for p in required_predicates if not isinstance(p, list)]
or_predicates = [p for p in required_predicates if isinstance(p, list)]

# Initialize predicate_subjects with subjects having single predicates
predicate_subjects = dfRaw.filter(F.col("predicate").isin(single_predicates)) \
                         .groupBy("subject") \
                         .agg(F.countDistinct("predicate").alias("single_predicate_count")) \
                         .filter(F.col("single_predicate_count") == len(single_predicates))

# Handle OR predicates (e.g., at least one of orderInOffice or order)
for or_predicate_group in or_predicates:
    predicate_subjects = predicate_subjects.join(
        dfRaw.filter(F.col("predicate").isin(or_predicate_group))
             .select("subject")
             .distinct(),
        on="subject",
        how="inner"
    )

# Step 2: Get labels for these subjects
labels_df = dfRaw.filter(F.col("predicate") == "http://www.w3.org/2000/01/rdf-schema#label") \
                 .select("subject", "object") \
                 .withColumnRenamed("object", "label")

# Step 3: Join with subjects and count occurrences of each label
label_counts = labels_df.join(predicate_subjects, on="subject", how="inner") \
                       .groupBy("subject", "label") \
                       .agg(F.count("*").alias("label_count"))

# Step 4: Get the most common label per subject
label_window = Window.partitionBy("subject").orderBy(F.col("label_count").desc())
most_common_labels = label_counts.withColumn("rn", F.row_number().over(label_window)) \
                                .filter(F.col("rn") == 1) \
                                .select("subject", "label") \
                                .distinct()

# Step 5: Final result
result_df = most_common_labels.orderBy("subject") \
                             .select("subject", "label")

# Show the results
print("Subjects with all required predicates and their most common labels:")
result_df.show(200, truncate=False)
# Out:
# Subjects with all required predicates and their most common labels:
# [Stage 508:=====================================================> (70 + 2) / 72]
# +------------------------------------+-------------------------+
# |subject                             |label                    |
# +------------------------------------+-------------------------+
# |https://global.dbpedia.org/id/123ePs|Fidel V. Ramos           |
# |https://global.dbpedia.org/id/12DcKK|George H. W. Bush        |
# |https://global.dbpedia.org/id/12EpJE|Jimmy Carter             |
# |https://global.dbpedia.org/id/1y533 |George W. Bush           |
# |https://global.dbpedia.org/id/3AMic |Woodrow Wilson           |
# |https://global.dbpedia.org/id/3BASN |Boris Yeltsin            |
# |https://global.dbpedia.org/id/3C6Qj |James A. Garfield        |
# |https://global.dbpedia.org/id/3DCUj |Ulysses S. Grant         |
# |https://global.dbpedia.org/id/3F36c |Grover Cleveland         |
# |https://global.dbpedia.org/id/3FJhb |Warren G. Harding        |
# |https://global.dbpedia.org/id/3FKYg |Herbert Hoover           |
# |https://global.dbpedia.org/id/3Hyz1 |Rutherford B. Hayes      |
# |https://global.dbpedia.org/id/3KXoH |Calvin Coolidge          |
# |https://global.dbpedia.org/id/4x8DR |Franklin Delano Roosevelt|
# |https://global.dbpedia.org/id/54Scf |Josip Broz Tito          |
# |https://global.dbpedia.org/id/56fEx |Gerald Ford              |
# |https://global.dbpedia.org/id/56odt |John F. Kennedy          |
# |https://global.dbpedia.org/id/57Lcb |Ronald Reagan            |
# |https://global.dbpedia.org/id/57h75 |Dwight D. Eisenhower     |
# |https://global.dbpedia.org/id/B6dR  |Bill Clinton             |
# |https://global.dbpedia.org/id/DeRC  |Martin Van Buren         |
# |https://global.dbpedia.org/id/Dorr  |John Quincy Adams        |
# |https://global.dbpedia.org/id/E6QS  |James Madison            |
# |https://global.dbpedia.org/id/WWKh  |Xi Jinping               |
# +------------------------------------+-------------------------+
